# %% [markdown]
# # 2. Preprocessing
# This notebook follows our [initial data exploration](Exploration.ipynb) and refines the dataset we will be using in the project.
#
# * [Finalize working subset](#subset)
# * [Normalize](#normalize)
# * [Validate](#validate)

# %%
import os, re
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from collections import Counter
from IPython.core.display import display, HTML
# %matplotlib inline

# %%
# all available:
with open('header','r') as source:
    FEATURES = source.read().strip().split(',')

# leave 2019 out due to procedural change affecting the data?
YEARS = np.arange(2010, 2020)

# %% [markdown]
# <a name="subset"></a>
# #### 1. Finalize subset

# %%
# features we are going to use (we keep original unique-key for the reference to the data source):
PICK = ('Unique Key,Agency,Complaint Type,Descriptor,Created Date,Closed Date,Address Type,Location Type,'
        'Incident Zip,Incident Address,Street Name,City,Borough,Latitude,Longitude').split(',')
INDEX = [FEATURES.index(f) for f in PICK]

# %%
# links to the exploration summary for reference
links = []
for i in INDEX[1:]:
    links.append('<li><a href="Data.html#2010-{}" target="_blank">{}</a></li>'.format(i, FEATURES[i]))
display(HTML('<ul>{}</ul>'.format(''.join(links))))
# Out:
# <ul><li><a href="Data.html#2010-3" target="_blank">Agency</a></li><li><a href="Data.html#2010-5" target="_blank">Complaint Type</a></li><li><a href="Data.html#2010-6" target="_blank">Descriptor</a></li><li><a href="Data.html#2010-1" target="_blank">Created Date</a></li><li><a href="Data.html#2010-2" target="_blank">Closed Date</a></li><li><a href="Data.html#2010-15" target="_blank">Address Type</a></li><li><a href="Data.html#2010-7" target="_blank">Location Type</a></li><li><a href="Data.html#2010-8" target="_blank">Incident Zip</a></li><li><a href="Data.html#2010-9" target="_blank">Incident Address</a></li><li><a href="Data.html#2010-10" target="_blank">Street Name</a></li><li><a href="Data.html#2010-16" target="_blank">City</a></li><li><a href="Data.html#2010-25" target="_blank">Borough</a></li><li><a href="Data.html#2010-38" target="_blank">Latitude</a></li><li><a href="Data.html#2010-39" target="_blank">Longitude</a></li></ul>

# %%
# get the filtered feature-subsets
with open('pick','w') as jobs:
    for Y in YEARS:
        jobs.write('awk -F, -v OFS=\',\' \'BEGIN{FPAT="([^,]*)|(\\"[^\\"]+\\")"}{'
                   'print $'+ ',$'.join([str(i + 1) for i in INDEX]) +'}\' '
                   './data/'+ str(Y) +'.clean.csv > ./data/'+ str(Y) +'.csv\n')
        
# !parallel --jobs 10 < pick

# %% [markdown]
# <a name="normalize"></a>
# #### 2. Normalize
# In the [the exploration-notebook](Exploration.ipynb) we generated value-dictionaries for all categorical features, we can use those for the data encoding and schema-normalization. First we refine them: take the values with some threshold count to filter out the "bad" entries; and normalize some categorical fields like *Street Name*.
#
# We can use generated dictionaries or the tokenizer function from the eploration-notebook to help us figure out how we can normalize the values in the "standard" fields like *Street Name*.
#
# Observations: some entries are abbreviated, others not; some numbers have ordinal suffix, other do not. Below is the normalization strategy we end up with after eyeballing feature-dictionaries and tokens:

# %%
sub = ['STREET ST',
       'AVENUE AVE',
       'EAST E',
       'WEST W',
       'BOULEVARD BLVD',
       'PLACE PL',
       'ROAD RD',
       'PARKWAY PKWY',
       'DRIVE DR',
       'BRIDGE BR',
       'SOUTH S',
       'NORTH N',
       'HIGHWAY HWY',
       'ISLAND ISL',
       'SAINT ST',
       'LANE LN',
       'EXPY EXPWY',
       'EXPRESSWAY EXPWY']

with open('normalize','w') as job:
    job.write("#!/bin/bash\n\n")
    # remove hashes: #123
    cmd = ['sed -e \'s/\#//g\' < ./data/$1.csv']
    # abbreviate
    for s in sub:
        long, short = s.split()
        cmd.append('sed -e \'s/{}/{}/g\''.format(long, short))
    # remove ordinal suffix
    for i,s in enumerate(('TH ST ND RD' + ' TH' * 6).split()):
        cmd.append('sed -e \'s/{}{}/{}/g\''.format(i, s, i))
    # remove dots: p.o. E.
    cmd.append('sed -e \'s/\.//g\' > ./data/$1.clean.csv\n')
    job.write(' | '.join(cmd))
    
# !chmod +x normalize

# %%
with open('jobs','w') as jobs:
    for y in YEARS:
        jobs.write('./normalize {}\n'.format(y))
    todo, n = [], len(YEARS)
    # add corresponding dictionaries
    for name in os.listdir('data'):
        if name[:5] == 'dict-' and int(name[5:-4]) in INDEX:
            jobs.write('./normalize dict-{}\n'.format(name[5:-4]))
            todo.append('<li><a href="#d{}" target="_blank">{}</a></li>'\
                            .format(name[5:-4], FEATURES[int(name[5:-4])]))
            n += 1

# 10 main files + n dictionaries
print('{} jobs total to run, then review:'.format(n))
# we might need to re-aggregate those dictionaries
display(HTML('<ul>{}</ul>'.format(''.join(todo))))
# Out:
# 20 jobs total to run, then review:
# <ul><li><a href="#d8" target="_blank">Incident Zip</a></li><li><a href="#d25" target="_blank">Borough</a></li><li><a href="#d10" target="_blank">Street Name</a></li><li><a href="#d7" target="_blank">Location Type</a></li><li><a href="#d6" target="_blank">Descriptor</a></li><li><a href="#d15" target="_blank">Address Type</a></li><li><a href="#d9" target="_blank">Incident Address</a></li><li><a href="#d16" target="_blank">City</a></li><li><a href="#d5" target="_blank">Complaint Type</a></li><li><a href="#d3" target="_blank">Agency</a></li></ul>

# %%
# 20 jobs with 10 cores
# !parallel --jobs 10 < jobs

# %%
# feature index and, if necessery, local version
index, local = {}, {}

# %% [markdown]
# Next, we look into the features from the list above one by one (only those which need the index):
# <a name="d10"></a>
# ##### Street Name

# %%
# load preprocessed summary
data = pd.read_csv('./data/dict-{}.clean.csv'.format(FEATURES.index('Street Name')))
# check for NaN befor setting idex (it may not be unique after processing)
data.shape[0], data.dropna().shape[0]
# Out:
# (37920, 7645)

# %%
# regroup after normalization
data = data.dropna().groupby('value').sum().reset_index()
data.shape[0]
# Out:
# 7307

# %% [markdown]
# More could be done here:

# %%
# put w[est] e[ast] n[orth] s[outh] at the end
def rearrange(x):
    w = str(x).split()
    if len(w) > 0 and w[0] in ['W','E','S','N']:
        return ' '.join(w[1:] + [w[0]])
    return x

rearrange('E Some Street')
# Out:
# 'Some Street E'

# %%
# put w[est] e[ast] n[orth] s[outh] at the end
data['value']  = data['value'].apply(rearrange)
# regroup after rearrange
data = data.groupby('value').sum()
data.shape[0]
# Out:
# 7130

# %%
data = data.sort_values('total', ascending = False).astype(int)
# check less common
data.tail()
# Out:
#                                 2010  2011  2012  2013  2014  2015  2016  \
# value
# ROSENTHAL PL                       1     3     1     2     1     2     2
# NEW ENGLAND THRUWAY SERVICE RD     1     1     1     1     2     3     1
# PONTON AVE                         1     1     1     3     1     1     1
# OLD COUNTRY RD                     1     1     2     2     3     1     2
# CENTREVILLE AVE                    1     1     1     1     1     2     2
#
#                                 2017  2018  2019  total
# value
# ROSENTHAL PL                       2     2     1     17
# NEW ENGLAND THRUWAY SERVICE RD     1     1     4     16
# PONTON AVE                         1     3     2     15
# OLD COUNTRY RD                     1     1     1     15
# CENTREVILLE AVE                    1     1     1     12

# %%
# save final for indexing
data.to_csv('./data/index-{}.csv'.format(FEATURES.index('Street Name')))

# %% [markdown]
# <a name="d3"></a>
# ##### Agency

# %%
data = pd.read_csv('./data/dict-{}.clean.csv'.format(FEATURES.index('Agency'))).set_index('value')
data.shape[0], data.dropna().shape[0]
# Out:
# (31, 17)

# %%
def highlight_nan(x):
    return 'color: crimson' if pd.isnull(x) or x == 0 else ''

data[data.isnull().any(axis = 1)].fillna(0).astype(int).style.applymap(highlight_nan)
# Out:
# <style  type="text/css" >
#     #T_ee812fc4_4d2b_11ea_a0e6_14dae9c2e866row0_col0 {
#             color:  crimson;
#         }    #T_ee812fc4_4d2b_11ea_a0e6_14dae9c2e866row1_col8 {
#             color:  crimson;
#         }    #T_ee812fc4_4d2b_11ea_a0e6_14dae9c2e866row1_col9 {
#             color:  crimson;
#         }    #T_ee812fc4_4d2b_11ea_a0e6_14dae9c2e866row2_col0 {
#             color:  crimson;
#         }    #T_ee812fc4_4d2b_11ea_a0e6_14dae9c2e866row2_col1 {
#             color:  crimson;
#         }    #T_ee812fc4_4d2b_11ea_a0e6_14dae9c2e866row2_col2 {
#             color:  crimson;
#         }    #T_ee812fc4_4d2b_11ea_a0e6_14dae9c2e866row2_col3 {
#             color:  crimson;
#         }    #T_ee812fc4_4d2b_11ea_a0e6_14dae9c2e866row2_col4 {
#             color:  crimson;
#         }    #T_ee812fc4_4d2b_11ea_a0e6_14dae9c2e866row2_col5 {
#             color:  crimson;
#         }    #T_ee812fc4_4d2b_11ea_a0e6_14dae9c2e866row2_col6 {
#             color:  crimson;
#         }    #T_ee812fc4_4d2b_11ea_a0e6_14dae9c2e866row3_col0 {
#             color:  crimson;
#         }    #T_ee812fc4_4d2b_11ea_a0e6_14dae9c2e866row3_col2 {
#             color:  crimson;
#         }    #T_ee812fc4_4d2b_11ea_a0e6_14dae9c2e866row3_col3 {
#             color:  crimson;
#         }    #T_ee812fc4_4d2b_11ea_a0e6_14dae9c2e866row3_col4 {
#             color:  crimson;
#         }    #T_ee812fc4_4d2b_11ea_a0e6_14dae9c2e866row3_col5 {
#             color:  crimson;
#         }    #T_ee812fc4_4d2b_11ea_a0e6_14dae9c2e866row4_col0 {
#             color:  crimson;
#         }    #T_ee812fc4_4d2b_11ea_a0e6_14dae9c2e866row4_col1 {
#             color:  crimson;
#         }    #T_ee812fc4_4d2b_11ea_a0e6_14dae9c2e866row4_col2 {
#             color:  crimson;
#         }    #T_ee812fc4_4d2b_11ea_a0e6_14dae9c2e866row4_col3 {
#             color:  crimson;
#         }    #T_ee812fc4_4d2b_11ea_a0e6_14dae9c2e866row4_col4 {
#             color:  crimson;
#         }    #T_ee812fc4_4d2b_11ea_a0e6_14dae9c2e866row4_col5 {
#             color:  crimson;
#         }    #T_ee812fc4_4d2b_11ea_a0e6_14dae9c2e866row4_col6 {
#             color:  crimson;
#         }    #T_ee812fc4_4d2b_11ea_a0e6_14dae9c2e866row5_col0 {
#             color:  crimson;
#         }    #T_ee812fc4_4d2b_11ea_a0e6_14dae9c2e866row5_col1 {
#             color:  crimson;
#         }    #T_ee812fc4_4d2b_11ea_a0e6_14dae9c2e866row5_col2 {
#             color:  crimson;
#         }    #T_ee812fc4_4d2b_11ea_a0e6_14dae9c2e866row5_col3 {
#             color:  crimson;
#         }    #T_ee812fc4_4d2b_11ea_a0e6_14dae9c2e866row5_col4 {
#             color:  crimson;
#         }    #T_ee812fc4_4d2b_11ea_a0e6_14dae9c2e866row5_col5 {
#             color:  crimson;
#         }    #T_ee812fc4_4d2b_11ea_a0e6_14dae9c2e866row5_col6 {
#             color:  crimson;
#         }    #T_ee812fc4_4d2b_11ea_a0e6_14dae9c2e866row5_col7 {
#             color:  crimson;
#         }    #T_ee812fc4_4d2b_11ea_a0e6_14dae9c2e866row5_col8 {
#             color:  crimson;
#         }    #T_ee812fc4_4d2b_11ea_a0e6_14dae9c2e866row6_col0 {
#             color:  crimson;
#         }    #T_ee812fc4_4d2b_11ea_a0e6_14dae9c2e866row6_col1 {
#             color:  crimson;
#         }    #T_ee812fc4_4d2b_11ea_a0e6_14dae9c2e866row6_col2 {
#             color:  crimson;
#         }    #T_ee812fc4_4d2b_11ea_a0e6_14dae9c2e866row6_col3 {
#             color:  crimson;
#         }    #T_ee812fc4_4d2b_11ea_a0e6_14dae9c2e866row6_col4 {
#             color:  crimson;
#         }    #T_ee812fc4_4d2b_11ea_a0e6_14dae9c2e866row6_col5 {
#             color:  crimson;
#         }    #T_ee812fc4_4d2b_11ea_a0e6_14dae9c2e866row7_col0 {
#             color:  crimson;
#         }    #T_ee812fc4_4d2b_11ea_a0e6_14dae9c2e866row7_col1 {
#             color:  crimson;
#         }    #T_ee812fc4_4d2b_11ea_a0e6_14dae9c2e866row7_col2 {
#             color:  crimson;
#         }    #T_ee812fc4_4d2b_11ea_a0e6_14dae9c2e866row7_col3 {
#             color:  crimson;
#         }    #T_ee812fc4_4d2b_11ea_a0e6_14dae9c2e866row7_col4 {
#             color:  crimson;
#         }    #T_ee812fc4_4d2b_11ea_a0e6_14dae9c2e866row7_col5 {
#             color:  crimson;
#         }    #T_ee812fc4_4d2b_11ea_a0e6_14dae9c2e866row7_col7 {
#             color:  crimson;
#         }    #T_ee812fc4_4d2b_11ea_a0e6_14dae9c2e866row7_col8 {
#             color:  crimson;
#         }    #T_ee812fc4_4d2b_11ea_a0e6_14dae9c2e866row7_col9 {
#             color:  crimson;
#         }    #T_ee812fc4_4d2b_11ea_a0e6_14dae9c2e866row8_col0 {
#             color:  crimson;
#         }    #T_ee812fc4_4d2b_11ea_a0e6_14dae9c2e866row8_col1 {
#             color:  crimson;
#         }    #T_ee812fc4_4d2b_11ea_a0e6_14dae9c2e866row8_col2 {
#             color:  crimson;
#         }    #T_ee812fc4_4d2b_11ea_a0e6_14dae9c2e866row8_col3 {
#             color:  crimson;
#         }    #T_ee812fc4_4d2b_11ea_a0e6_14dae9c2e866row8_col4 {
#             color:  crimson;
#         }    #T_ee812fc4_4d2b_11ea_a0e6_14dae9c2e866row8_col5 {
#             color:  crimson;
#         }    #T_ee812fc4_4d2b_11ea_a0e6_14dae9c2e866row8_col6 {
#             color:  crimson;
#         }    #T_ee812fc4_4d2b_11ea_a0e6_14dae9c2e866row8_col7 {
#             color:  crimson;
#         }    #T_ee812fc4_4d2b_11ea_a0e6_14dae9c2e866row9_col0 {
#             color:  crimson;
#         }    #T_ee812fc4_4d2b_11ea_a0e6_14dae9c2e866row9_col1 {
#             color:  crimson;
#         }    #T_ee812fc4_4d2b_11ea_a0e6_14dae9c2e866row9_col2 {
#             color:  crimson;
#         }    #T_ee812fc4_4d2b_11ea_a0e6_14dae9c2e866row9_col3 {
#             color:  crimson;
#         }    #T_ee812fc4_4d2b_11ea_a0e6_14dae9c2e866row9_col4 {
#             color:  crimson;
#         }    #T_ee812fc4_4d2b_11ea_a0e6_14dae9c2e866row9_col5 {
#             color:  crimson;
#         }    #T_ee812fc4_4d2b_11ea_a0e6_14dae9c2e866row9_col6 {
#             color:  crimson;
#         }    #T_ee812fc4_4d2b_11ea_a0e6_14dae9c2e866row10_col0 {
#             color:  crimson;
#         }    #T_ee812fc4_4d2b_11ea_a0e6_14dae9c2e866row10_col1 {
#             color:  crimson;
#         }    #T_ee812fc4_4d2b_11ea_a0e6_14dae9c2e866row10_col2 {
#             color:  crimson;
#         }    #T_ee812fc4_4d2b_11ea_a0e6_14dae9c2e866row10_col3 {
#             color:  crimson;
#         }    #T_ee812fc4_4d2b_11ea_a0e6_14dae9c2e866row10_col4 {
#             color:  crimson;
#         }    #T_ee812fc4_4d2b_11ea_a0e6_14dae9c2e866row10_col5 {
#             color:  crimson;
#         }    #T_ee812fc4_4d2b_11ea_a0e6_14dae9c2e866row10_col6 {
#             color:  crimson;
#         }    #T_ee812fc4_4d2b_11ea_a0e6_14dae9c2e866row11_col0 {
#             color:  crimson;
#         }    #T_ee812fc4_4d2b_11ea_a0e6_14dae9c2e866row11_col1 {
#             color:  crimson;
#         }    #T_ee812fc4_4d2b_11ea_a0e6_14dae9c2e866row11_col2 {
#             color:  crimson;
#         }    #T_ee812fc4_4d2b_11ea_a0e6_14dae9c2e866row11_col3 {
#             color:  crimson;
#         }    #T_ee812fc4_4d2b_11ea_a0e6_14dae9c2e866row11_col4 {
#             color:  crimson;
#         }    #T_ee812fc4_4d2b_11ea_a0e6_14dae9c2e866row11_col5 {
#             color:  crimson;
#         }    #T_ee812fc4_4d2b_11ea_a0e6_14dae9c2e866row11_col6 {
#             color:  crimson;
#         }    #T_ee812fc4_4d2b_11ea_a0e6_14dae9c2e866row11_col7 {
#             color:  crimson;
#         }    #T_ee812fc4_4d2b_11ea_a0e6_14dae9c2e866row11_col9 {
#             color:  crimson;
#         }    #T_ee812fc4_4d2b_11ea_a0e6_14dae9c2e866row12_col0 {
#             color:  crimson;
#         }    #T_ee812fc4_4d2b_11ea_a0e6_14dae9c2e866row12_col1 {
#             color:  crimson;
#         }    #T_ee812fc4_4d2b_11ea_a0e6_14dae9c2e866row12_col2 {
#             color:  crimson;
#         }    #T_ee812fc4_4d2b_11ea_a0e6_14dae9c2e866row12_col3 {
#             color:  crimson;
#         }    #T_ee812fc4_4d2b_11ea_a0e6_14dae9c2e866row12_col4 {
#             color:  crimson;
#         }    #T_ee812fc4_4d2b_11ea_a0e6_14dae9c2e866row12_col5 {
#             color:  crimson;
#         }    #T_ee812fc4_4d2b_11ea_a0e6_14dae9c2e866row12_col6 {
#             color:  crimson;
#         }    #T_ee812fc4_4d2b_11ea_a0e6_14dae9c2e866row12_col7 {
#             color:  crimson;
#         }    #T_ee812fc4_4d2b_11ea_a0e6_14dae9c2e866ro

# %%
# save final for indexing
data.sort_values('total', ascending = False).to_csv('./data/index-{}.csv'.format(FEATURES.index('Agency')))

# %% [markdown]
# <a name="d16"></a>
# ##### City

# %%
data = pd.read_csv('./data/dict-{}.clean.csv'.format(FEATURES.index('City')))
data.shape[0], data.dropna().shape[0]
# Out:
# (2489, 101)

# %%
data = data.groupby('value').sum().sort_values('total', ascending = False)
data.shape[0]
# Out:
# 2459

# %%
# check those NaNs
data.tail(100).astype(int).style.applymap(highlight_nan)
# Out:
# <style  type="text/css" >
#     #T_f14d67d6_4d2b_11ea_a0e6_14dae9c2e866row0_col0 {
#             color:  crimson;
#         }    #T_f14d67d6_4d2b_11ea_a0e6_14dae9c2e866row0_col1 {
#             color:  crimson;
#         }    #T_f14d67d6_4d2b_11ea_a0e6_14dae9c2e866row0_col2 {
#             color:  crimson;
#         }    #T_f14d67d6_4d2b_11ea_a0e6_14dae9c2e866row0_col3 {
#             color:  crimson;
#         }    #T_f14d67d6_4d2b_11ea_a0e6_14dae9c2e866row0_col5 {
#             color:  crimson;
#         }    #T_f14d67d6_4d2b_11ea_a0e6_14dae9c2e866row0_col6 {
#             color:  crimson;
#         }    #T_f14d67d6_4d2b_11ea_a0e6_14dae9c2e866row0_col7 {
#             color:  crimson;
#         }    #T_f14d67d6_4d2b_11ea_a0e6_14dae9c2e866row0_col8 {
#             color:  crimson;
#         }    #T_f14d67d6_4d2b_11ea_a0e6_14dae9c2e866row0_col9 {
#             color:  crimson;
#         }    #T_f14d67d6_4d2b_11ea_a0e6_14dae9c2e866row1_col0 {
#             color:  crimson;
#         }    #T_f14d67d6_4d2b_11ea_a0e6_14dae9c2e866row1_col1 {
#             color:  crimson;
#         }    #T_f14d67d6_4d2b_11ea_a0e6_14dae9c2e866row1_col2 {
#             color:  crimson;
#         }    #T_f14d67d6_4d2b_11ea_a0e6_14dae9c2e866row1_col3 {
#             color:  crimson;
#         }    #T_f14d67d6_4d2b_11ea_a0e6_14dae9c2e866row1_col5 {
#             color:  crimson;
#         }    #T_f14d67d6_4d2b_11ea_a0e6_14dae9c2e866row1_col6 {
#             color:  crimson;
#         }    #T_f14d67d6_4d2b_11ea_a0e6_14dae9c2e866row1_col7 {
#             color:  crimson;
#         }    #T_f14d67d6_4d2b_11ea_a0e6_14dae9c2e866row1_col8 {
#             color:  crimson;
#         }    #T_f14d67d6_4d2b_11ea_a0e6_14dae9c2e866row1_col9 {
#             color:  crimson;
#         }    #T_f14d67d6_4d2b_11ea_a0e6_14dae9c2e866row2_col0 {
#             color:  crimson;
#         }    #T_f14d67d6_4d2b_11ea_a0e6_14dae9c2e866row2_col1 {
#             color:  crimson;
#         }    #T_f14d67d6_4d2b_11ea_a0e6_14dae9c2e866row2_col2 {
#             color:  crimson;
#         }    #T_f14d67d6_4d2b_11ea_a0e6_14dae9c2e866row2_col4 {
#             color:  crimson;
#         }    #T_f14d67d6_4d2b_11ea_a0e6_14dae9c2e866row2_col5 {
#             color:  crimson;
#         }    #T_f14d67d6_4d2b_11ea_a0e6_14dae9c2e866row2_col6 {
#             color:  crimson;
#         }    #T_f14d67d6_4d2b_11ea_a0e6_14dae9c2e866row2_col7 {
#             color:  crimson;
#         }    #T_f14d67d6_4d2b_11ea_a0e6_14dae9c2e866row2_col8 {
#             color:  crimson;
#         }    #T_f14d67d6_4d2b_11ea_a0e6_14dae9c2e866row2_col9 {
#             color:  crimson;
#         }    #T_f14d67d6_4d2b_11ea_a0e6_14dae9c2e866row3_col0 {
#             color:  crimson;
#         }    #T_f14d67d6_4d2b_11ea_a0e6_14dae9c2e866row3_col2 {
#             color:  crimson;
#         }    #T_f14d67d6_4d2b_11ea_a0e6_14dae9c2e866row3_col3 {
#             color:  crimson;
#         }    #T_f14d67d6_4d2b_11ea_a0e6_14dae9c2e866row3_col4 {
#             color:  crimson;
#         }    #T_f14d67d6_4d2b_11ea_a0e6_14dae9c2e866row3_col5 {
#             color:  crimson;
#         }    #T_f14d67d6_4d2b_11ea_a0e6_14dae9c2e866row3_col6 {
#             color:  crimson;
#         }    #T_f14d67d6_4d2b_11ea_a0e6_14dae9c2e866row3_col7 {
#             color:  crimson;
#         }    #T_f14d67d6_4d2b_11ea_a0e6_14dae9c2e866row3_col8 {
#             color:  crimson;
#         }    #T_f14d67d6_4d2b_11ea_a0e6_14dae9c2e866row3_col9 {
#             color:  crimson;
#         }    #T_f14d67d6_4d2b_11ea_a0e6_14dae9c2e866row4_col0 {
#             color:  crimson;
#         }    #T_f14d67d6_4d2b_11ea_a0e6_14dae9c2e866row4_col1 {
#             color:  crimson;
#         }    #T_f14d67d6_4d2b_11ea_a0e6_14dae9c2e866row4_col2 {
#             color:  crimson;
#         }    #T_f14d67d6_4d2b_11ea_a0e6_14dae9c2e866row4_col3 {
#             color:  crimson;
#         }    #T_f14d67d6_4d2b_11ea_a0e6_14dae9c2e866row4_col4 {
#             color:  crimson;
#         }    #T_f14d67d6_4d2b_11ea_a0e6_14dae9c2e866row4_col5 {
#             color:  crimson;
#         }    #T_f14d67d6_4d2b_11ea_a0e6_14dae9c2e866row4_col6 {
#             color:  crimson;
#         }    #T_f14d67d6_4d2b_11ea_a0e6_14dae9c2e866row4_col8 {
#             color:  crimson;
#         }    #T_f14d67d6_4d2b_11ea_a0e6_14dae9c2e866row4_col9 {
#             color:  crimson;
#         }    #T_f14d67d6_4d2b_11ea_a0e6_14dae9c2e866row5_col0 {
#             color:  crimson;
#         }    #T_f14d67d6_4d2b_11ea_a0e6_14dae9c2e866row5_col1 {
#             color:  crimson;
#         }    #T_f14d67d6_4d2b_11ea_a0e6_14dae9c2e866row5_col3 {
#             color:  crimson;
#         }    #T_f14d67d6_4d2b_11ea_a0e6_14dae9c2e866row5_col4 {
#             color:  crimson;
#         }    #T_f14d67d6_4d2b_11ea_a0e6_14dae9c2e866row5_col5 {
#             color:  crimson;
#         }    #T_f14d67d6_4d2b_11ea_a0e6_14dae9c2e866row5_col6 {
#             color:  crimson;
#         }    #T_f14d67d6_4d2b_11ea_a0e6_14dae9c2e866row5_col7 {
#             color:  crimson;
#         }    #T_f14d67d6_4d2b_11ea_a0e6_14dae9c2e866row5_col8 {
#             color:  crimson;
#         }    #T_f14d67d6_4d2b_11ea_a0e6_14dae9c2e866row5_col9 {
#             color:  crimson;
#         }    #T_f14d67d6_4d2b_11ea_a0e6_14dae9c2e866row6_col0 {
#             color:  crimson;
#         }    #T_f14d67d6_4d2b_11ea_a0e6_14dae9c2e866row6_col1 {
#             color:  crimson;
#         }    #T_f14d67d6_4d2b_11ea_a0e6_14dae9c2e866row6_col2 {
#             color:  crimson;
#         }    #T_f14d67d6_4d2b_11ea_a0e6_14dae9c2e866row6_col3 {
#             color:  crimson;
#         }    #T_f14d67d6_4d2b_11ea_a0e6_14dae9c2e866row6_col4 {
#             color:  crimson;
#         }    #T_f14d67d6_4d2b_11ea_a0e6_14dae9c2e866row6_col5 {
#             color:  crimson;
#         }    #T_f14d67d6_4d2b_11ea_a0e6_14dae9c2e866row6_col6 {
#             color:  crimson;
#         }    #T_f14d67d6_4d2b_11ea_a0e6_14dae9c2e866row6_col8 {
#             color:  crimson;
#         }    #T_f14d67d6_4d2b_11ea_a0e6_14dae9c2e866row6_col9 {
#             color:  crimson;
#         }    #T_f14d67d6_4d2b_11ea_a0e6_14dae9c2e866row7_col1 {
#             color:  crimson;
#         }    #T_f14d67d6_4d2b_11ea_a0e6_14dae9c2e866row7_col2 {
#             color:  crimson;
#         }    #T_f14d67d6_4d2b_11ea_a0e6_14dae9c2e866row7_col3 {
#             color:  crimson;
#         }    #T_f14d67d6_4d2b_11ea_a0e6_14dae9c2e866row7_col4 {
#             color:  crimson;
#         }    #T_f14d67d6_4d2b_11ea_a0e6_14dae9c2e866row7_col5 {
#             color:  crimson;
#         }    #T_f14d67d6_4d2b_11ea_a0e6_14dae9c2e866row7_col6 {
#             color:  crimson;
#         }    #T_f14d67d6_4d2b_11ea_a0e6_14dae9c2e866row7_col7 {
#             color:  crimson;
#         }    #T_f14d67d6_4d2b_11ea_a0e6_14dae9c2e866row7_col8 {
#             color:  crimson;
#         }    #T_f14d67d6_4d2b_11ea_a0e6_14dae9c2e866row7_col9 {
#             color:  crimson;
#         }    #T_f14d67d6_4d2b_11ea_a0e6_14dae9c2e866row8_col1 {
#             color:  crimson;
#         }    #T_f14d67d6_4d2b_11ea_a0e6_14dae9c2e866row8_col2 {
#             color:  crimson;
#         }    #T_f14d67d6_4d2b_11ea_a0e6_14dae9c2e866row8_col3 {
#             color:  crimson;
#         }    #T_f14d67d6_4d2b_11ea_a0e6_14dae9c2e866row8_col4 {
#             color:  crimson;
#         }    #T_f14d67d6_4d2b_11ea_a0e6_14dae9c2e866row8_col5 {
#             color:  crimson;
#         }    #T_f14d67d6_4d2b_11ea_a0e6_14dae9c2e866row8_col6 {
#             color:  crimson;
#         }    #T_f14d67d6_4d2b_11ea_a0e6_14dae9c2e866row8_col7 {
#             color:  crimson;
#         }    #T_f14d67d6_4d2b_11ea_a0e6_14dae9c2e866row8_col8 {
#             color:  crimson;
#         }    #T_f14d67d6_4d2b_11ea_a0e6_14dae9c2e866row8_col9 {
#             color:  crimson;
#         }    #T_f14d67d6_4d2b_11ea_a0e6_14dae9c2e866row9_col1 {
#             color:  crimson;
#         }    #T_f14d67d6_4d2b_11ea_a0e6_14dae9c2e866row9_col2 {
#             color:  crimson;
#         }    #T_f14d67d6_4d2b_11ea_a0e6_14dae9c2e866row9_col3 {
#             color:  crimson;
#         }    #T_f14d67d6_4d2b_11ea_a0e6_14dae9c2e866row9_col4 {
#             color:  crimson;
#         }    #T_f14d67d6_4d2b_11ea_a0e6_14dae9c2e866row9_col5 {
#             co

# %% [markdown]
# Looks like NaN here is either misspelling or a bad entry (ANYWHERE): we drop it all.

# %%
data = data[data > 0].dropna()
data.astype(int)
# Out:
#                    2010    2011    2012    2013    2014    2015    2016  \
# value
# BROOKLYN         604021  590496  535163  540828  631071  678905  702602
# NEW YORK         365642  351366  329152  356915  412335  457738  503476
# BRONX            380242  361459  322314  325332  378414  399300  425238
# STATEN ISL       100545   99986   86908   85349  102751  108311  109933
# JAMAICA           51422   49151   43343   40961   47743   54054   54005
# ...                 ...     ...     ...     ...     ...     ...     ...
# LAKE SUCCESS          3       3       3       2       5       1       2
# FRANKLIN SQUARE       4       2       3       3       1       4       4
# MT VERNON             6       1       3       2       2       1       1
# TEANECK               3       1       1       3       4       3       3
# ROCHESTER             1       4       1       2       3       2       1
#
#                    2017    2018    2019    total
# value
# BROOKLYN         755846  848926  743305  6631163
# NEW YORK         469055  498035  450914  4194628
# BRONX            435441  466654  417778  3912172
# STATEN ISL       129089  152943  125941  1101756
# JAMAICA           58853   69990   62007   531529
# ...                 ...     ...     ...      ...
# LAKE SUCCESS          3       3       2       27
# FRANKLIN SQUARE       2       3       1       27
# MT VERNON             2       3       3       24
# TEANECK               1       2       2       23
# ROCHESTER             2       2       2       20
#
# [102 rows x 11 columns]

# %%
# save final for indexing
data.to_csv('./data/index-{}.csv'.format(FEATURES.index('City')))

# %% [markdown]
# <a name="d25"></a>
# ##### Borough

# %%
data = pd.read_csv('./data/dict-{}.clean.csv'.format(FEATURES.index('Borough'))).set_index('value')
data
# Out:
#               2010    2011    2012    2013    2014    2015    2016    2017  \
# value
# BROOKLYN    383526  563807  557259  573486  657103  704974  725597  778470
# QUEENS      380845  424625  417416  404295  480069  531704  538563  599274
# MANHATTAN   267492  352022  356601  387033  435849  481980  526205  491462
# BRONX       198900  336380  341966  349021  395612  416324  441916  453024
# STATEN ISL   89926  100424   88726   89093  105252  110549  112197  131318
#
#               2018    2019    total
# value
# BROOKLYN    870439  772479  6587140
# QUEENS      677120  605531  5059442
# MANHATTAN   520179  488028  4306851
# BRONX       484707  439161  3857011
# STATEN ISL  154665  129208  1111358

# %%
# save final for indexing
data.to_csv('./data/index-{}.csv'.format(FEATURES.index('Borough')))

# %% [markdown]
# <a name="d7"></a>
# ##### Location Type

# %%
data = pd.read_csv('./data/dict-{}.clean.csv'.format(FEATURES.index('Location Type')))
data.shape[0], data.dropna().shape[0]
# Out:
# (167, 95)

# %%
data = data.groupby('value').sum().sort_values('total', ascending = False)
data.fillna(0).astype(int).style.applymap(highlight_nan)
# Out:
# <style  type="text/css" >
#     #T_f65d8102_4d2b_11ea_a0e6_14dae9c2e866row12_col0 {
#             color:  crimson;
#         }    #T_f65d8102_4d2b_11ea_a0e6_14dae9c2e866row15_col5 {
#             color:  crimson;
#         }    #T_f65d8102_4d2b_11ea_a0e6_14dae9c2e866row15_col6 {
#             color:  crimson;
#         }    #T_f65d8102_4d2b_11ea_a0e6_14dae9c2e866row15_col7 {
#             color:  crimson;
#         }    #T_f65d8102_4d2b_11ea_a0e6_14dae9c2e866row15_col8 {
#             color:  crimson;
#         }    #T_f65d8102_4d2b_11ea_a0e6_14dae9c2e866row15_col9 {
#             color:  crimson;
#         }    #T_f65d8102_4d2b_11ea_a0e6_14dae9c2e866row26_col0 {
#             color:  crimson;
#         }    #T_f65d8102_4d2b_11ea_a0e6_14dae9c2e866row26_col7 {
#             color:  crimson;
#         }    #T_f65d8102_4d2b_11ea_a0e6_14dae9c2e866row26_col9 {
#             color:  crimson;
#         }    #T_f65d8102_4d2b_11ea_a0e6_14dae9c2e866row31_col0 {
#             color:  crimson;
#         }    #T_f65d8102_4d2b_11ea_a0e6_14dae9c2e866row31_col1 {
#             color:  crimson;
#         }    #T_f65d8102_4d2b_11ea_a0e6_14dae9c2e866row36_col0 {
#             color:  crimson;
#         }    #T_f65d8102_4d2b_11ea_a0e6_14dae9c2e866row36_col1 {
#             color:  crimson;
#         }    #T_f65d8102_4d2b_11ea_a0e6_14dae9c2e866row38_col0 {
#             color:  crimson;
#         }    #T_f65d8102_4d2b_11ea_a0e6_14dae9c2e866row38_col3 {
#             color:  crimson;
#         }    #T_f65d8102_4d2b_11ea_a0e6_14dae9c2e866row38_col4 {
#             color:  crimson;
#         }    #T_f65d8102_4d2b_11ea_a0e6_14dae9c2e866row38_col5 {
#             color:  crimson;
#         }    #T_f65d8102_4d2b_11ea_a0e6_14dae9c2e866row38_col6 {
#             color:  crimson;
#         }    #T_f65d8102_4d2b_11ea_a0e6_14dae9c2e866row38_col7 {
#             color:  crimson;
#         }    #T_f65d8102_4d2b_11ea_a0e6_14dae9c2e866row38_col8 {
#             color:  crimson;
#         }    #T_f65d8102_4d2b_11ea_a0e6_14dae9c2e866row38_col9 {
#             color:  crimson;
#         }    #T_f65d8102_4d2b_11ea_a0e6_14dae9c2e866row42_col0 {
#             color:  crimson;
#         }    #T_f65d8102_4d2b_11ea_a0e6_14dae9c2e866row42_col1 {
#             color:  crimson;
#         }    #T_f65d8102_4d2b_11ea_a0e6_14dae9c2e866row42_col2 {
#             color:  crimson;
#         }    #T_f65d8102_4d2b_11ea_a0e6_14dae9c2e866row49_col0 {
#             color:  crimson;
#         }    #T_f65d8102_4d2b_11ea_a0e6_14dae9c2e866row49_col1 {
#             color:  crimson;
#         }    #T_f65d8102_4d2b_11ea_a0e6_14dae9c2e866row52_col0 {
#             color:  crimson;
#         }    #T_f65d8102_4d2b_11ea_a0e6_14dae9c2e866row52_col1 {
#             color:  crimson;
#         }    #T_f65d8102_4d2b_11ea_a0e6_14dae9c2e866row52_col2 {
#             color:  crimson;
#         }    #T_f65d8102_4d2b_11ea_a0e6_14dae9c2e866row52_col3 {
#             color:  crimson;
#         }    #T_f65d8102_4d2b_11ea_a0e6_14dae9c2e866row52_col4 {
#             color:  crimson;
#         }    #T_f65d8102_4d2b_11ea_a0e6_14dae9c2e866row52_col5 {
#             color:  crimson;
#         }    #T_f65d8102_4d2b_11ea_a0e6_14dae9c2e866row59_col0 {
#             color:  crimson;
#         }    #T_f65d8102_4d2b_11ea_a0e6_14dae9c2e866row59_col3 {
#             color:  crimson;
#         }    #T_f65d8102_4d2b_11ea_a0e6_14dae9c2e866row59_col4 {
#             color:  crimson;
#         }    #T_f65d8102_4d2b_11ea_a0e6_14dae9c2e866row59_col5 {
#             color:  crimson;
#         }    #T_f65d8102_4d2b_11ea_a0e6_14dae9c2e866row59_col6 {
#             color:  crimson;
#         }    #T_f65d8102_4d2b_11ea_a0e6_14dae9c2e866row59_col7 {
#             color:  crimson;
#         }    #T_f65d8102_4d2b_11ea_a0e6_14dae9c2e866row59_col8 {
#             color:  crimson;
#         }    #T_f65d8102_4d2b_11ea_a0e6_14dae9c2e866row59_col9 {
#             color:  crimson;
#         }    #T_f65d8102_4d2b_11ea_a0e6_14dae9c2e866row60_col0 {
#             color:  crimson;
#         }    #T_f65d8102_4d2b_11ea_a0e6_14dae9c2e866row60_col1 {
#             color:  crimson;
#         }    #T_f65d8102_4d2b_11ea_a0e6_14dae9c2e866row60_col2 {
#             color:  crimson;
#         }    #T_f65d8102_4d2b_11ea_a0e6_14dae9c2e866row60_col3 {
#             color:  crimson;
#         }    #T_f65d8102_4d2b_11ea_a0e6_14dae9c2e866row60_col4 {
#             color:  crimson;
#         }    #T_f65d8102_4d2b_11ea_a0e6_14dae9c2e866row60_col5 {
#             color:  crimson;
#         }    #T_f65d8102_4d2b_11ea_a0e6_14dae9c2e866row60_col6 {
#             color:  crimson;
#         }    #T_f65d8102_4d2b_11ea_a0e6_14dae9c2e866row60_col7 {
#             color:  crimson;
#         }    #T_f65d8102_4d2b_11ea_a0e6_14dae9c2e866row61_col0 {
#             color:  crimson;
#         }    #T_f65d8102_4d2b_11ea_a0e6_14dae9c2e866row61_col1 {
#             color:  crimson;
#         }    #T_f65d8102_4d2b_11ea_a0e6_14dae9c2e866row62_col8 {
#             color:  crimson;
#         }    #T_f65d8102_4d2b_11ea_a0e6_14dae9c2e866row64_col0 {
#             color:  crimson;
#         }    #T_f65d8102_4d2b_11ea_a0e6_14dae9c2e866row64_col1 {
#             color:  crimson;
#         }    #T_f65d8102_4d2b_11ea_a0e6_14dae9c2e866row64_col2 {
#             color:  crimson;
#         }    #T_f65d8102_4d2b_11ea_a0e6_14dae9c2e866row64_col3 {
#             color:  crimson;
#         }    #T_f65d8102_4d2b_11ea_a0e6_14dae9c2e866row64_col4 {
#             color:  crimson;
#         }    #T_f65d8102_4d2b_11ea_a0e6_14dae9c2e866row65_col0 {
#             color:  crimson;
#         }    #T_f65d8102_4d2b_11ea_a0e6_14dae9c2e866row65_col1 {
#             color:  crimson;
#         }    #T_f65d8102_4d2b_11ea_a0e6_14dae9c2e866row65_col2 {
#             color:  crimson;
#         }    #T_f65d8102_4d2b_11ea_a0e6_14dae9c2e866row65_col3 {
#             color:  crimson;
#         }    #T_f65d8102_4d2b_11ea_a0e6_14dae9c2e866row65_col4 {
#             color:  crimson;
#         }    #T_f65d8102_4d2b_11ea_a0e6_14dae9c2e866row65_col5 {
#             color:  crimson;
#         }    #T_f65d8102_4d2b_11ea_a0e6_14dae9c2e866row68_col0 {
#             color:  crimson;
#         }    #T_f65d8102_4d2b_11ea_a0e6_14dae9c2e866row68_col1 {
#             color:  crimson;
#         }    #T_f65d8102_4d2b_11ea_a0e6_14dae9c2e866row69_col0 {
#             color:  crimson;
#         }    #T_f65d8102_4d2b_11ea_a0e6_14dae9c2e866row69_col1 {
#             color:  crimson;
#         }    #T_f65d8102_4d2b_11ea_a0e6_14dae9c2e866row69_col2 {
#             color:  crimson;
#         }    #T_f65d8102_4d2b_11ea_a0e6_14dae9c2e866row69_col3 {
#             color:  crimson;
#         }    #T_f65d8102_4d2b_11ea_a0e6_14dae9c2e866row69_col4 {
#             color:  crimson;
#         }    #T_f65d8102_4d2b_11ea_a0e6_14dae9c2e866row69_col5 {
#             color:  crimson;
#         }    #T_f65d8102_4d2b_11ea_a0e6_14dae9c2e866row71_col0 {
#             color:  crimson;
#         }    #T_f65d8102_4d2b_11ea_a0e6_14dae9c2e866row71_col1 {
#             color:  crimson;
#         }    #T_f65d8102_4d2b_11ea_a0e6_14dae9c2e866row71_col2 {
#             color:  crimson;
#         }    #T_f65d8102_4d2b_11ea_a0e6_14dae9c2e866row73_col0 {
#             color:  crimson;
#         }    #T_f65d8102_4d2b_11ea_a0e6_14dae9c2e866row73_col1 {
#             color:  crimson;
#         }    #T_f65d8102_4d2b_11ea_a0e6_14dae9c2e866row73_col2 {
#             color:  crimson;
#         }    #T_f65d8102_4d2b_11ea_a0e6_14dae9c2e866row73_col3 {
#             color:  crimson;
#         }    #T_f65d8102_4d2b_11ea_a0e6_14dae9c2e866row73_col4 {
#             color:  crimson;
#         }    #T_f65d8102_4d2b_11ea_a0e6_14dae9c2e866row73_col5 {
#             color:  crimson;
#         }    #T_f65d8102_4d2b_11ea_a0e6_14dae9c2e866row74_col0 {
#             color:  crimson;
#         }    #T_f65d8102_4d2b_11ea_a0e6_14dae9c2e866row74_col1 {
#             color:  crimson;
#         }    #T_f65d8102_4d2b_11ea_a0e6_14dae9c2e866row74_col2 {
#             color:  crimson;
#         }    #T_f65d8102_4d2b_11ea_a0e6_14dae9c2e866row74_col3 {
#             color:  crimson;
#         }    #T_f65d8102_4d2b_11ea_a0e6_14dae9c2e866row74_col4 {
#             color:  crimson;
#         }    #T_f65d8102_4d2b_11ea_a0e6_14dae9c2e866row74_col5 {
#             color:  cr

# %%
# let's try to reduce this index (dwelling, building, 1-2, 1-,2-,3-...)
with open('location-type','w') as output:
    output.write('value,label\n"{}",\n'.format('",\n"'.join(data.index.tolist())))

# load after we done with it and saved as location-type-local
labels = pd.read_csv('location-type-local', dtype = str).set_index('value')

# %%
# see with our reduction
test = data.join(labels).reset_index().drop('value', axis = 1)\
        .groupby('label').sum().sort_values('total', ascending = False)

test.astype(int).style.applymap(highlight_nan)
# Out:
# <style  type="text/css" >
#     #T_f65d8103_4d2b_11ea_a0e6_14dae9c2e866row20_col0 {
#             color:  crimson;
#         }    #T_f65d8103_4d2b_11ea_a0e6_14dae9c2e866row20_col1 {
#             color:  crimson;
#         }    #T_f65d8103_4d2b_11ea_a0e6_14dae9c2e866row24_col0 {
#             color:  crimson;
#         }    #T_f65d8103_4d2b_11ea_a0e6_14dae9c2e866row24_col1 {
#             color:  crimson;
#         }    #T_f65d8103_4d2b_11ea_a0e6_14dae9c2e866row24_col2 {
#             color:  crimson;
#         }    #T_f65d8103_4d2b_11ea_a0e6_14dae9c2e866row24_col3 {
#             color:  crimson;
#         }    #T_f65d8103_4d2b_11ea_a0e6_14dae9c2e866row24_col4 {
#             color:  crimson;
#         }    #T_f65d8103_4d2b_11ea_a0e6_14dae9c2e866row24_col5 {
#             color:  crimson;
#         }    #T_f65d8103_4d2b_11ea_a0e6_14dae9c2e866row28_col0 {
#             color:  crimson;
#         }    #T_f65d8103_4d2b_11ea_a0e6_14dae9c2e866row28_col1 {
#             color:  crimson;
#         }    #T_f65d8103_4d2b_11ea_a0e6_14dae9c2e866row31_col0 {
#             color:  crimson;
#         }    #T_f65d8103_4d2b_11ea_a0e6_14dae9c2e866row31_col1 {
#             color:  crimson;
#         }    #T_f65d8103_4d2b_11ea_a0e6_14dae9c2e866row34_col0 {
#             color:  crimson;
#         }    #T_f65d8103_4d2b_11ea_a0e6_14dae9c2e866row40_col0 {
#             color:  crimson;
#         }    #T_f65d8103_4d2b_11ea_a0e6_14dae9c2e866row40_col1 {
#             color:  crimson;
#         }    #T_f65d8103_4d2b_11ea_a0e6_14dae9c2e866row40_col2 {
#             color:  crimson;
#         }    #T_f65d8103_4d2b_11ea_a0e6_14dae9c2e866row40_col3 {
#             color:  crimson;
#         }    #T_f65d8103_4d2b_11ea_a0e6_14dae9c2e866row40_col4 {
#             color:  crimson;
#         }    #T_f65d8103_4d2b_11ea_a0e6_14dae9c2e866row40_col5 {
#             color:  crimson;
#         }    #T_f65d8103_4d2b_11ea_a0e6_14dae9c2e866row40_col6 {
#             color:  crimson;
#         }    #T_f65d8103_4d2b_11ea_a0e6_14dae9c2e866row42_col0 {
#             color:  crimson;
#         }    #T_f65d8103_4d2b_11ea_a0e6_14dae9c2e866row42_col1 {
#             color:  crimson;
#         }    #T_f65d8103_4d2b_11ea_a0e6_14dae9c2e866row42_col4 {
#             color:  crimson;
#         }    #T_f65d8103_4d2b_11ea_a0e6_14dae9c2e866row42_col5 {
#             color:  crimson;
#         }    #T_f65d8103_4d2b_11ea_a0e6_14dae9c2e866row42_col6 {
#             color:  crimson;
#         }    #T_f65d8103_4d2b_11ea_a0e6_14dae9c2e866row42_col7 {
#             color:  crimson;
#         }    #T_f65d8103_4d2b_11ea_a0e6_14dae9c2e866row42_col8 {
#             color:  crimson;
#         }    #T_f65d8103_4d2b_11ea_a0e6_14dae9c2e866row42_col9 {
#             color:  crimson;
#         }    #T_f65d8103_4d2b_11ea_a0e6_14dae9c2e866row43_col4 {
#             color:  crimson;
#         }    #T_f65d8103_4d2b_11ea_a0e6_14dae9c2e866row43_col5 {
#             color:  crimson;
#         }    #T_f65d8103_4d2b_11ea_a0e6_14dae9c2e866row43_col6 {
#             color:  crimson;
#         }    #T_f65d8103_4d2b_11ea_a0e6_14dae9c2e866row43_col9 {
#             color:  crimson;
#         }    #T_f65d8103_4d2b_11ea_a0e6_14dae9c2e866row44_col0 {
#             color:  crimson;
#         }    #T_f65d8103_4d2b_11ea_a0e6_14dae9c2e866row44_col1 {
#             color:  crimson;
#         }    #T_f65d8103_4d2b_11ea_a0e6_14dae9c2e866row44_col3 {
#             color:  crimson;
#         }    #T_f65d8103_4d2b_11ea_a0e6_14dae9c2e866row44_col4 {
#             color:  crimson;
#         }    #T_f65d8103_4d2b_11ea_a0e6_14dae9c2e866row44_col5 {
#             color:  crimson;
#         }    #T_f65d8103_4d2b_11ea_a0e6_14dae9c2e866row44_col6 {
#             color:  crimson;
#         }</style><table id="T_f65d8103_4d2b_11ea_a0e6_14dae9c2e866" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >2010</th>        <th class="col_heading level0 col1" >2011</th>        <th class="col_heading level0 col2" >2012</th>        <th class="col_heading level0 col3" >2013</th>        <th class="col_heading level0 col4" >2014</th>        <th class="col_heading level0 col5" >2015</th>        <th class="col_heading level0 col6" >2016</th>        <th class="col_heading level0 col7" >2017</th>        <th class="col_heading level0 col8" >2018</th>        <th class="col_heading level0 col9" >2019</th>        <th class="col_heading level0 col10" >total</th>    </tr>    <tr>        <th class="index_name level0" >label</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_f65d8103_4d2b_11ea_a0e6_14dae9c2e866level0_row0" class="row_heading level0 row0" >RESIDENTIAL</th>
#                         <td id="T_f65d8103_4d2b_11ea_a0e6_14dae9c2e866row0_col0" class="data row0 col0" >858650</td>
#                         <td id="T_f65d8103_4d2b_11ea_a0e6_14dae9c2e866row0_col1" class="data row0 col1" >844176</td>
#                         <td id="T_f65d8103_4d2b_11ea_a0e6_14dae9c2e866row0_col2" class="data row0 col2" >740720</td>
#                         <td id="T_f65d8103_4d2b_11ea_a0e6_14dae9c2e866row0_col3" class="data row0 col3" >773944</td>
#                         <td id="T_f65d8103_4d2b_11ea_a0e6_14dae9c2e866row0_col4" class="data row0 col4" >858099</td>
#                         <td id="T_f65d8103_4d2b_11ea_a0e6_14dae9c2e866row0_col5" class="data row0 col5" >884256</td>
#                         <td id="T_f65d8103_4d2b_11ea_a0e6_14dae9c2e866row0_col6" class="data row0 col6" >877710</td>
#                         <td id="T_f65d8103_4d2b_11ea_a0e6_14dae9c2e866row0_col7" class="data row0 col7" >864989</td>
#                         <td id="T_f65d8103_4d2b_11ea_a0e6_14dae9c2e866row0_col8" class="data row0 col8" >889439</td>
#                         <td id="T_f65d8103_4d2b_11ea_a0e6_14dae9c2e866row0_col9" class="data row0 col9" >735094</td>
#                         <td id="T_f65d8103_4d2b_11ea_a0e6_14dae9c2e866row0_col10" class="data row0 col10" >8327077</td>
#             </tr>
#             <tr>
#                         <th id="T_f65d8103_4d2b_11ea_a0e6_14dae9c2e866level0_row1" class="row_heading level0 row1" >STREET</th>
#                         <td id="T_f65d8103_4d2b_11ea_a0e6_14dae9c2e866row1_col0" class="data row1 col0" >454005</td>
#                         <td id="T_f65d8103_4d2b_11ea_a0e6_14dae9c2e866row1_col1" class="data row1 col1" >443082</td>
#                         <td id="T_f65d8103_4d2b_11ea_a0e6_14dae9c2e866row1_col2" class="data row1 col2" >423574</td>
#                         <td id="T_f65d8103_4d2b_11ea_a0e6_14dae9c2e866row1_col3" class="data row1 col3" >440609</td>
#                         <td id="T_f65d8103_4d2b_11ea_a0e6_14dae9c2e866row1_col4" class="data row1 col4" >527311</td>
#                         <td id="T_f65d8103_4d2b_11ea_a0e6_14dae9c2e866row1_col5" class="data row1 col5" >622561</td>
#                         <td id="T_f65d8103_4d2b_11ea_a0e6_14dae9c2e866row1_col6" class="data row1 col6" >732369</td>
#                         <td id="T_f65d8103_4d2b_11ea_a0e6_14dae9c2e866row1_col7" class="data row1 col7" >865577</td>
#                         <td id="T_f65d8103_4d2b_11ea_a0e6_14dae9c2e866row1_col8" class="data row1 col8" >1065585</td>
#                         <td id="T_f65d8103_4d2b_11ea_a0e6_14dae9c2e866row1_col9" class="data row1 col9" >946872</td>
#                         <td id="T_f65d8103_4d2b_11ea_a0e6_14dae9c2e866row1_col10" class="data row1 col10" >6521545</td>
#             </tr>
#             <tr>
#                         <th id="T_f65d8103_4d2b_11ea_a0e6_14dae9c2e866level0_row2" class="row_heading level0 row2" >FOOD/ENTERTAINMENT</th>
#                         <td id="T_f65d8103_4d2b_11ea_a0e6_14dae9c2e866row2_col0" class="data row2 col0" >24808</td>
#                         <td id="T_f65d8103_4d2b_11ea_a0e6_14

# %%
# save final for indexing
data.join(labels).to_csv('./data/index-{}.csv'.format(FEATURES.index('Location Type')))
with open('./data/local-{}'.format(FEATURES.index('Location Type')), 'w') as output:
    output.write('\n'.join(test.index.tolist()))

# %%
# use local index for location-type
local['Location Type'] = labels.to_dict()['label']

# start from 1 (we reserve 0 for NaN)
new_index = { v:str(i + 1) for i,v in enumerate(test.index.tolist()) }
# replace with new
for value in local['Location Type']:
    key = local['Location Type'][value]
    local['Location Type'][value] = new_index[key] if key in new_index else ''

# %% [markdown]
# <a name="d15"></a>
# ##### Address Type

# %%
data = pd.read_csv('./data/dict-{}.clean.csv'.format(FEATURES.index('Address Type')))
data.shape[0], data.dropna().shape[0]
# Out:
# (5, 4)

# %%
data = data.groupby('value').sum().sort_values('total', ascending = False)
data.astype(int).style.applymap(highlight_nan)

# %%
# save final for indexing
data.to_csv('./data/index-{}.csv'.format(FEATURES.index('Address Type')))

# %%
# clean pandas floating-poin nightmare
# !sed -i 's/\.0,/,/g' ./data/index*
# !sed -i ':a;N;$!ba;s/\.0\n/\n/g' ./data/index*

# %%
# !ls -l data/index*
# Out:
# -rw-r--r-- 1 arcta arcta 341170 Feb  9 16:09 data/index-10.csv
# -rw-r--r-- 1 arcta arcta    446 Feb  9 16:09 data/index-15.csv
# -rw-r--r-- 1 arcta arcta   5446 Feb  9 16:09 data/index-16.csv
# -rw-r--r-- 1 arcta arcta    492 Feb  9 16:09 data/index-25.csv
# -rw-r--r-- 1 arcta arcta   1650 Feb  9 16:09 data/index-3.csv
# -rw-r--r-- 1 arcta arcta  10354 Feb  9 16:09 data/index-7.csv

# %%
# make lookup dict for the index we created above
for name in os.listdir('data'):
    if name[:6] == 'index-':
        data = pd.read_csv('./data/{}'.format(name))
        feature = FEATURES[int(name[6:-4])]
        values = data['value'].tolist()
        # use local if available
        if feature in local:
            index[feature] = { x:local[feature][x] for i,x in enumerate(values) }
        else:
            index[feature] = { x:str(i+1) for i,x in enumerate(values) }

# %%
# use clean dict
for name in os.listdir('data'):
    if name[:5] == 'dict-' and name[-10:] == '.clean.csv':
        pd.read_csv('./data/{}'.format(name)).set_index('value').to_csv('./data/{}.csv'.format(name[:-10]))

# %% [markdown]
# <a name="validate"></a>
# #### 3. Validate & Index
# Note: this encoding meant for the storage, not for the model training.

# %%
# use only first numeric token, ignore the rest (apt and redundant st name)
def address(x):
    x = x or ''
    x = str(x).strip()
    if len(x) > 0:
        w = ' '.join(re.split(r'\D+', x)).strip().split()
        if len(w) > 0:
            return w[0]
    return ''

address('8768a the street')
# Out:
# '8768'

# %%
# remove non-NY or invalid zipcodes
def zipcode(x):
    try:
        x = int(str(x)[:5])
    except ValueError:
        return ''
    else:
        if 20000 > x > 10000: # NY
            return str(x)
        return ''

# %%
# !head ./data/summary-2010-39.csv
# Out:
# -73.8661287701622,972
# -73.92714580413967,895
# -73.93211429429171,863
# -73.92248337295159,755
# -73.94900486982377,706
# -73.9603425781195,679
# -73.78309546512209,642
# -73.96199943182411,641
# -73.90193505991684,603
# -73.886775529518,600

# %%
# !head ./data/summary-2010-38.csv
# Out:
# 40.87225493792927,972
# 40.861937381906316,895
# 40.85372003211803,863
# 40.84848255580813,755
# 40.6385706801265,706
# 40.67115570695576,679
# 40.64391915466994,642
# 40.71157025286253,641
# 40.81651295693585,603
# 40.83370844901697,600

# %%
# remove non-NY coords
def latitude(x):
    x = x or ''
    x = str(x).strip()
    if len(x) > 2 and x[0] == '4':
        return '{}.{}'.format(x[:2], x[2:])
    return ''

# %%
def longitude(x):
    x = x or ''
    x = str(x).strip()
    if len(x) > 3 and x[:2] == '-7':
        return '{}.{}'.format(x[:3], x[3:])
    return ''

# %% [markdown]
# Date and time transformation:

# %%
def to_iso(x):
    d = x.split('/')
    if len(d) < 3:
        return ''
    return '{}-{}-{}'.format(d[2],d[0],d[1])

to_iso('04/11/2018')
# Out:
# '2018-04-11'

# %%
def afternoon(x):
    t = x.split(':')
    if len(t) == 3 and int(t[0]) <= 12:
        return '{}:{}:{}'.format(int(t[0]) + 12, t[1], t[2])
    return ''

afternoon('09:45:14')
# Out:
# '21:45:14'

# %%
def daytime(x):
    t = x.split(':')
    if len(t) == 3:
        return '{:.2f}'.format((int(t[0]) + int(t[1])/60)/24)
    return ''

daytime('12:30:00')
# Out:
# '0.52'

# %%
# normalize text
def text(x):
    return (' '.join(re.sub(r'[\W\d_]+',' ', x).strip().split())).lower()

# %%
# put it all together
def proc(y):
    # load year data
    data = pd.read_csv('./data/{}.clean.csv'.format(y), header = None, dtype = str).astype(str)
    n,_ = data.shape
    data.columns = PICK
    data = data.set_index('Unique Key')
    
    # remove street-name from the address
    data['Incident Address'] = data['Incident Address'].apply(address)
    
    # use normalized street-name
    data['Street Name'] = data['Street Name'].apply(rearrange)
    
    # check zipcode value
    data['Incident Zip'] = data['Incident Zip'].apply(zipcode)
    
    # check lat-lng
    data['Latitude'] = data['Latitude'].apply(latitude)
    data['Longitude'] = data['Longitude'].apply(longitude)
    
    # normalize text
    data['Complaint Type'] = data['Complaint Type'].apply(text)
    data['Descriptor'] = data['Descriptor'].apply(text)
    
    # index categorical content
    for name in index:
        data[name] = data[name].apply(lambda x:index[name][x] if x in index[name] else '')
        
    # normalize date pd.to_datetime(data['Created Date'], infer_datetime_format = True)
    D = data['Created Date'].str.split(' ', expand = True)
    D.columns = ['Date','Time','AmPm']
    data['Time'] = D.apply(lambda x:x['Time'] if x['AmPm'] == 'AM' else afternoon(x['Time']), axis = 1)
    data['AmPm'] = data['Time'].apply(daytime)
    data['Created Date'] = D['Date'].apply(to_iso)
    
    # we need only date part here if available
    available = ~data['Closed Date'].isna()
    data.loc[available,'Closed Date'] = data.loc[available,'Closed Date'].apply(lambda x:to_iso(x.split()[0]))
    
    # check for NaN
    presence = ['{}: {:.2%}'.format(f, 1 - (data[f] == '').sum()/n) for f in PICK[1:]]
    print('\n\n{}:\n\t{}'.format(y,'\n'.join(presence)))
    # save final
    data.sort_values(['Created Date','AmPm']).to_csv('./data/{}.csv'.format(y))

# %% [markdown]
# <a name="summary"></a>

# %%
# check 2010 first
data = proc(2010)
# Out:
# 2010:
# 	Agency: 100.00%
# Complaint Type: 100.00%
# Descriptor: 99.88%
# Created Date: 100.00%
# Closed Date: 97.61%
# Address Type: 96.22%
# Location Type: 70.18%
# Incident Zip: 93.12%
# Incident Address: 73.09%
# Street Name: 74.79%
# City: 93.18%
# Borough: 65.00%
# Latitude: 88.23%
# Longitude: 88.23%

# %%
# !head data/2010.csv

# %%
# save final labels
# !head -n1 ./data/2010.csv > features-local

# %%
# get the rest done
for y in YEARS[1:]: proc(y)
# Out:
# 2011:
# 	Agency: 100.00%
# Complaint Type: 100.00%
# Descriptor: 99.89%
# Created Date: 100.00%
# Closed Date: 93.25%
# Address Type: 95.58%
# Location Type: 71.42%
# Incident Zip: 92.72%
# Incident Address: 73.89%
# Street Name: 75.52%
# City: 92.79%
# Borough: 90.60%
# Latitude: 87.67%
# Longitude: 87.67%
#
#
# 2012:
# 	Agency: 100.00%
# Complaint Type: 100.00%
# Descriptor: 99.88%
# Created Date: 100.00%
# Closed Date: 98.29%
# Address Type: 95.85%
# Location Type: 70.93%
# Incident Zip: 92.90%
# Incident Address: 75.25%
# Street Name: 76.71%
# City: 92.95%
# Borough: 98.10%
# Latitude: 89.01%
# Longitude: 89.00%
#
#
# 2013:
# 	Agency: 100.00%
# Complaint Type: 100.00%
# Descriptor: 99.86%
# Created Date: 100.00%
# Closed Date: 98.10%
# Address Type: 94.06%
# Location Type: 71.71%
# Incident Zip: 91.60%
# Incident Address: 76.69%
# Street Name: 78.24%
# City: 91.64%
# Borough: 97.99%
# Latitude: 88.33%
# Longitude: 88.33%
#
#
# 2014:
# 	Agency: 100.00%
# Complaint Type: 100.00%
# Descriptor: 99.89%
# Created Date: 100.00%
# Closed Date: 98.20%
# Address Type: 95.81%
# Location Type: 71.64%
# Incident Zip: 93.76%
# Incident Address: 77.41%
# Street Name: 79.18%
# City: 93.81%
# Borough: 98.10%
# Latitude: 90.79%
# Longitude: 90.79%
#
#
# 2015:
# 	Agency: 100.00%
# Complaint Type: 100.00%
# Descriptor: 99.90%
# Created Date: 100.00%
# Closed Date: 97.85%
# Address Type: 95.62%
# Location Type: 71.55%
# Incident Zip: 93.56%
# Incident Address: 78.13%
# Street Name: 79.83%
# City: 93.58%
# Borough: 97.60%
# Latitude: 90.69%
# Longitude: 90.69%
#
#
# 2016:
# 	Agency: 100.00%
# Complaint Type: 100.00%
# Descriptor: 99.89%
# Created Date: 100.00%
# Closed Date: 97.96%
# Address Type: 96.00%
# Location Type: 74.05%
# Incident Zip: 94.39%
# Incident Address: 80.09%
# Street Name: 81.42%
# City: 94.42%
# Borough: 98.04%
# Latitude: 91.67%
# Longitude: 91.67%
#
#
# 2017:
# 	Agency: 100.00%
# Complaint Type: 100.00%
# Descriptor: 99.85%
# Created Date: 100.00%
# Closed Date: 98.09%
# Address Type: 96.58%
# Location Type: 75.72%
# Incident Zip: 95.02%
# Incident Address: 81.34%
# Street Name: 82.32%
# City: 95.04%
# Borough: 98.46%
# Latitude: 92.11%
# Longitude: 92.10%
#
#
# 2018:
# 	Agency: 100.00%
# Complaint Type: 100.00%
# Descriptor: 99.86%
# Created Date: 100.00%
# Closed Date: 97.99%
# Address Type: 96.82%
# Location Type: 76.80%
# Incident Zip: 95.56%
# Incident Address: 83.47%
# Street Name: 84.22%
# City: 95.59%
# Borough: 98.51%
# Latitude: 92.94%
# Longitude: 92.94%
#
#
# 2019:
# 	Agency: 100.00%
# Complaint Type: 100.00%
# Descriptor: 99.84%
# Created Date: 100.00%
# Closed Date: 96.05%
# Address Type: 73.23%
# Location Type: 74.12%
# Incident Zip: 96.81%
# Incident Address: 86.71%
# Street Name: 88.64%
# City: 94.26%
# Borough: 99.09%
# Latitude: 94.69%
# Longitude: 94.69%

# %% [markdown]
# Observation: the missing data trend shows consistent decline.

# %%
# !rm ./data/*.clean.csv
# !rm ./data/summary-20*

# %% [markdown]
# The textual features *Complaint Type, Descriptor* are processed in [the topic-modeling notebook](Taxonomy.ipynb). At this point we are ready to import preprocessed csv into the database.
